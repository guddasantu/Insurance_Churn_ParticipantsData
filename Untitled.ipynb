# %%
##Imported Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
##import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.patches as mpatches
import time

# Classifier Libraries
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import collections


# Other Libraries
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
from collections import Counter
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
from sklearn.model_selection import GridSearchCV
warnings.filterwarnings("ignore")
from sklearn.ensemble import GradientBoostingClassifier 
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train.shape,test.shape
# Out:
# ((33908, 17), (11303, 16))

# %%
train.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -0.276515  -0.424429   1.344997  -0.012283   0.076230   1.076648
# 1   0.853573   0.150991   0.503892  -0.979179  -0.569351  -0.411453
# 2   0.947747  -0.173832   1.825628  -0.703478   0.076230  -0.411453
# 3   0.853573  -0.381404   0.984523  -0.039464  -0.569351  -0.411453
# 4   1.324443   1.590527  -1.178318  -0.097711  -0.246560  -0.411453
#
#    feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  \
# 0   0.182198          3          0          1           0           0
# 1  -0.251940          4          1          2           0           1
# 2  -0.251940          6          1          2           0           0
# 3  -0.251940          4          0          2           0           1
# 4  -0.251940          0          1          1           0           0
#
#    feature_12  feature_13  feature_14  feature_15  labels
# 0           0           0          10           2       1
# ...

# %%
train.labels.value_counts()
# Out:
# 0    29941
# 1     3967
# Name: labels, dtype: int64

# %%
train.isna().sum()
# Out:
# feature_0     0
# feature_1     0
# feature_2     0
# feature_3     0
# feature_4     0
# feature_5     0
# feature_6     0
# feature_7     0
# feature_8     0
# feature_9     0
# feature_10    0
# feature_11    0
# feature_12    0
# feature_13    0
# feature_14    0
# feature_15    0
# labels        0
# dtype: int64

# %%
X=train.drop(['labels'],axis=1)
y=train['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 16), (8477, 16), (25431,), (8477,))

# %%
from sklearn.linear_model import LogisticRegression
lnr_class = LogisticRegression()
lnr_class.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(lnr_class, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = lnr_class.predict(X_test)
print(accuracy_score(y_test, y_predict))
pd.crosstab(y_test, y_predict)
# Out:
# 0.8892296803114309
# col_0      0    1
# labels
# 0       7336  129
# 1        810  202

# %%
model=RandomForestClassifier(n_estimators=200)
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
pd.crosstab(y_test, y_predict)
# Out:
# 0.9049191931107703
# col_0      0    1
# labels
# 0       7251  214
# 1        592  420

# %%
f1 = f1_score(y_test, y_predict)
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.510328

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      7465
#            1       0.66      0.42      0.51      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.79      0.69      0.73      8477
# weighted avg       0.89      0.90      0.90      8477

# %%
predict_test1 = model.predict(test)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(X_train,y_train)

model = RandomForestClassifier(n_estimators=25, random_state=11)
model.fit(X_train, y_train)

clf_rf_5 = RandomForestClassifier()      
clr_rf_5 = clf_rf_5.fit(X_train,y_train)
importances = clr_rf_5.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf_rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest

plt.figure(1, figsize=(14, 13))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices],rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 3 (0.289804)
# 2. feature 1 (0.108320)
# 3. feature 0 (0.102081)
# 4. feature 2 (0.089876)
# 5. feature 14 (0.087520)
# 6. feature 15 (0.053622)
# 7. feature 5 (0.050318)
# 8. feature 7 (0.049666)
# 9. feature 4 (0.037910)
# 10. feature 9 (0.028151)
# 11. feature 11 (0.026063)
# 12. feature 8 (0.022609)
# 13. feature 13 (0.021409)
# 14. feature 6 (0.020556)
# 15. feature 12 (0.010268)
# 16. feature 10 (0.001826)

# %%
train.columns
# Out:
# Index(['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4',
#        'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9',
#        'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14',
#        'feature_15', 'labels'],
#       dtype='object')

# %%
df=train[['feature_3','feature_1','feature_0','feature_2','feature_14','feature_15','feature_5','feature_7','feature_4','labels']]

# %%
X=df.drop(['labels'],axis=1)
y=df['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 9), (8477, 9), (25431,), (8477,))

# %%
from sklearn.linear_model import LogisticRegression
lnr_class = LogisticRegression()
lnr_class.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(lnr_class, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = lnr_class.predict(X_test)
print(accuracy_score(y_test, y_predict))
pd.crosstab(y_test, y_predict)
# Out:
# 0.8869883213400968
# col_0      0    1
# labels
# 0       7363  102
# 1        856  156

# %% [markdown]
# Following code gave F1 score 58

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_leaf=4,class_weight="balanced", criterion='entropy')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
pd.crosstab(y_test, y_predict)
# Out:
# 0.8953639259171877
# col_0      0    1
# labels
# 0       6976  489
# 1        398  614

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7465
#            1       0.56      0.61      0.58      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.75      0.77      0.76      8477
# weighted avg       0.90      0.90      0.90      8477

# %% [markdown]
# ### Following Code gave 60.5 F1 Score

# %%
model=RandomForestClassifier(n_estimators=100,min_samples_leaf=4,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8959537572254336
# col_0      0    1
# labels
# 0       6898  567
# 1        315  697
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.55      0.69      0.61      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.75      0.81      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
model=RandomForestClassifier(n_estimators=100,min_samples_leaf=4,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8958357909637844
# col_0      0    1
# labels
# 0       6964  501
# 1        382  630
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7465
#            1       0.56      0.62      0.59      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.75      0.78      0.76      8477
# weighted avg       0.90      0.90      0.90      8477

# %%
predict_test1 = model.predict(test)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
model=RandomForestClassifier(n_estimators=100,min_samples_leaf=6,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8872242538633951
# col_0      0    1
# labels
# 0       6771  694
# 1        262  750
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      7465
#            1       0.52      0.74      0.61      1012
#
#     accuracy                           0.89      8477
#    macro avg       0.74      0.82      0.77      8477
# weighted avg       0.91      0.89      0.90      8477

# %%
predict_test1 = model.predict(test)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
711+245
# Out:
# 956

# %%
688+255
# Out:
# 943

# %%
feature_scores = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
# feature_3     0.442337
# feature_14    0.081708
# feature_1     0.064008
# feature_0     0.060322
# feature_13    0.056417
# feature_2     0.053804
# feature_5     0.045019
# feature_15    0.043506
# feature_11    0.042196
# feature_7     0.026146
# feature_4     0.026116
# feature_6     0.022410
# feature_9     0.014996
# feature_8     0.011908
# feature_12    0.008761
# feature_10    0.000345
# dtype: float64

# %%
train1 = train[['feature_3','feature_14','feature_1','feature_0','feature_13','feature_2','feature_5','feature_15','feature_11','labels']]

# %%
X=train1.drop(['labels'],axis=1)
y=train1['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 9), (8477, 9), (25431,), (8477,))

# %% [markdown]
# ####  61% accuracy got

# %%
model=RandomForestClassifier(n_estimators=150,min_samples_leaf=4,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8973693523652235
# col_0      0    1
# labels
# 0       6896  569
# 1        301  711
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.56      0.70      0.62      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.76      0.81      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
test1=test[['feature_3','feature_14','feature_1','feature_0','feature_13','feature_2','feature_5','feature_15','feature_11']]

# %%
predict_test1 = model.predict(test1)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %% [markdown]
# #### 61.26

# %%
model=RandomForestClassifier(n_estimators=150,min_samples_leaf=6,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.887814085171641
# col_0      0    1
# labels
# 0       6766  699
# 1        252  760
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93      7465
#            1       0.52      0.75      0.62      1012
#
#     accuracy                           0.89      8477
#    macro avg       0.74      0.83      0.77      8477
# weighted avg       0.91      0.89      0.90      8477

# %%
predict_test1 = model.predict(test1)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
model=RandomForestClassifier(n_estimators=250,min_samples_leaf=4,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8968974873186268
# col_0      0    1
# labels
# 0       6895  570
# 1        304  708
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.55      0.70      0.62      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.76      0.81      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
train2=train.copy()

# %%
#train2 = train[['feature_3','feature_14','feature_1','feature_0','feature_13','feature_2','labels']]

# %%
X_train.columns
# Out:
# Index(['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
#        'feature_13', 'feature_5', 'feature_11', 'feature_15', 'feature_7',
#        'feature_4', 'feature_2'],
#       dtype='object')

# %%
test2=test[['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
       'feature_13', 'feature_5', 'feature_11', 'feature_15', 'feature_7',
       'feature_4']]

# %%
X=train2.drop(['labels'],axis=1)
y=train2['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 16), (8477, 16), (25431,), (8477,))

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_leaf=4,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8959537572254336
# col_0      0    1
# labels
# 0       6903  562
# 1        320  692
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.55      0.68      0.61      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.75      0.80      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
feature_scores = pd.Series(model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
# feature_3     0.421746
# feature_14    0.080059
# feature_1     0.070179
# feature_0     0.067306
# feature_2     0.058941
# feature_13    0.051166
# feature_5     0.047578
# feature_11    0.040561
# feature_15    0.040283
# feature_7     0.030160
# feature_4     0.029600
# feature_6     0.022220
# feature_9     0.016710
# feature_8     0.013367
# feature_12    0.009704
# feature_10    0.000420
# dtype: float64

# %%
train2=train[['feature_3','feature_14','feature_1','feature_0','feature_2','feature_13','feature_5','feature_11','feature_15','feature_7','feature_4','labels']]

# %%
X=train2.drop(['labels'],axis=1)
y=train2['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 11), (8477, 11), (25431,), (8477,))

# %%
X_train.columns
# Out:
# Index(['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
#        'feature_13', 'feature_5', 'feature_11', 'feature_15', 'feature_7',
#        'feature_4'],
#       dtype='object')

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_leaf=5,class_weight="balanced", criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict)) 
# Check accuracy score 
print('Model accuracy score with native_country_41 variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_predict)))
# Out:
# 0.8899374778813259
# col_0      0    1
# labels
# 0       6808  657
# 1        276  736
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94      7465
#            1       0.53      0.73      0.61      1012
#
#     accuracy                           0.89      8477
#    macro avg       0.74      0.82      0.77      8477
# weighted avg       0.91      0.89      0.90      8477
#
# Model accuracy score with native_country_41 variable removed : 0.8899

# %%
train.labels.value_counts()
# Out:
# 0    29941
# 1     3967
# Name: labels, dtype: int64

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_leaf=4,class_weight={0:1.5,1:8.5}, criterion='gini')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict)) 
# Check accuracy score 
print('Model accuracy score with native_country_41 variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_predict)))
# Out:
# 0.9010263064763477
# col_0      0    1
# labels
# 0       6960  505
# 1        334  678
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7465
#            1       0.57      0.67      0.62      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.76      0.80      0.78      8477
# weighted avg       0.91      0.90      0.90      8477
#
# Model accuracy score with native_country_41 variable removed : 0.9010

# %%
model=RandomForestClassifier(n_estimators=450,min_samples_leaf=7,class_weight={0:1.5,1:8.5}, criterion='entropy')
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict)) 
# Check accuracy score 
print('Model accuracy score with native_country_41 variable removed : {0:0.4f}'. format(accuracy_score(y_test, y_predict)))
# Out:
# 0.8931225669458535
# col_0      0    1
# labels
# 0       6831  634
# 1        272  740
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.54      0.73      0.62      1012
#
#     accuracy                           0.89      8477
#    macro avg       0.75      0.82      0.78      8477
# weighted avg       0.91      0.89      0.90      8477
#
# Model accuracy score with native_country_41 variable removed : 0.8931

# %%
predict_test1 = model.predict(test2)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
params = {'depth':[2, 3, 4],
           'loss_function': ['Logloss', 'CrossEntropy'],
           'l2_leaf_reg':np.logspace(-20, -19, 3)
}
 
def catboost_GridSearchCV(X_train, y_train,  params,n_splits=5):
     ps = {'acc':0,
     'param': []
 }
param = catboost_GridSearchCV(X_train, y_train, params)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
## Hyper Parameter Optimization

params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
model1=RandomForestClassifier(n_estimators=100,min_samples_leaf=4,class_weight="balanced", criterion='entropy')
model1.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model1.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8897188912915274
# col_0      0    1
# labels
# 0       4131  365
# 1        196  395
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      4496
#            1       0.52      0.67      0.58       591
#
#     accuracy                           0.89      5087
#    macro avg       0.74      0.79      0.76      5087
# weighted avg       0.90      0.89      0.90      5087

# %%
y_predict = model1.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8897188912915274
# col_0      0    1
# labels
# 0       4131  365
# 1        196  395
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      4496
#            1       0.52      0.67      0.58       591
#
#     accuracy                           0.89      5087
#    macro avg       0.74      0.79      0.76      5087
# weighted avg       0.90      0.89      0.90      5087

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.94      4496
#            1       0.63      0.31      0.42       591
#
#     accuracy                           0.90      5087
#    macro avg       0.77      0.64      0.68      5087
# weighted avg       0.88      0.90      0.88      5087

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

model=CatBoostClassifier(n_estimators=200)
model.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model.predict(X_test)
print(accuracy_score(y_test, y_predict))
pd.crosstab(y_test, y_predict)
# Out:
# Learning rate set to 0.17564
# 0:	learn: 0.5121910	total: 38.5ms	remaining: 7.65s
# 1:	learn: 0.4274672	total: 51.3ms	remaining: 5.07s
# 2:	learn: 0.3609080	total: 67ms	remaining: 4.4s
# 3:	learn: 0.3230994	total: 78.7ms	remaining: 3.85s
# 4:	learn: 0.2940202	total: 90ms	remaining: 3.51s
# 5:	learn: 0.2764238	total: 99.8ms	remaining: 3.23s
# 6:	learn: 0.2671035	total: 111ms	remaining: 3.05s
# 7:	learn: 0.2587769	total: 121ms	remaining: 2.9s
# 8:	learn: 0.2528969	total: 132ms	remaining: 2.8s
# 9:	learn: 0.2466486	total: 145ms	remaining: 2.75s
# 10:	learn: 0.2424359	total: 155ms	remaining: 2.66s
# 11:	learn: 0.2401610	total: 172ms	remaining: 2.69s
# 12:	learn: 0.2378974	total: 183ms	remaining: 2.64s
# 13:	learn: 0.2358351	total: 199ms	remaining: 2.65s
# 14:	learn: 0.2328227	total: 211ms	remaining: 2.6s
# 15:	learn: 0.2303968	total: 220ms	remaining: 2.53s
# 16:	learn: 0.2288164	total: 231ms	remaining: 2.48s
# 17:	learn: 0.2268350	total: 241ms	remaining: 2.44s
# ...

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      7465
#            1       0.60      0.15      0.24      1012
#
#     accuracy                           0.89      8477
#    macro avg       0.75      0.57      0.59      8477
# weighted avg       0.86      0.89      0.86      8477

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
#from sklearn.grid_search import ParameterGrid
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from itertools import product, chain
from tqdm import tqdm

# %%
params = {'depth':[2, 3, 4],
              'loss_function': ['Logloss', 'CrossEntropy'],
              'l2_leaf_reg':np.logspace(-20, -19, 3)
    }
    
param =catboost_GridSearchCV(X_train, y_train, X_test, params, cat_features)

clf = CatBoostClassifier(iterations=2500,
                            loss_function = param['loss_function'],
                            depth=param['depth'],
                            l2_leaf_reg = param['l2_leaf_reg'],
                            eval_metric = 'Accuracy',
                            leaf_estimation_iterations = 10,
                            use_best_model=True
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a92e64c5e2d3> in <module>
#       4     }
#       5
# ----> 6 param =catboost_GridSearchCV(X_train, y_train, X_test, params, cat_features)
#       7
#       8 clf = CatBoostClassifier(iterations=2500,
#
# NameError: name 'catboost_GridSearchCV' is not defined

# %%
test.shape
# Out:
# (11303, 16)

# %%
from catboost import CatBoost
model=CatBoost()

grid = {'learning_rate': [0.03, 0.1],
        'depth': [4, 6, 10],
        'l2_leaf_reg': [1, 3, 5, 7, 9]}

grid_search_result = model.grid_search(grid, 
                                       X=X_train, 
                                       y=y_train, 
                                       plot=True)
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
import xgboost
n_estimators = 10
seed = 7
pipelines = []
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from imblearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from time import time
import scipy.stats as stats
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier)
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

pipelines.append(('MNB',
                  Pipeline([ ('MNB', MultinomialNB())
                              ])))

# pipelines.append(('SVC',
#                   Pipeline([ ('SVC', SVC(random_state=seed))
#                               ])))

pipelines.append(('CATBoost',
                   Pipeline([ ('CATBoost', lgb.LGBMClassifier())
                               ])))

pipelines.append(('RF',
                  Pipeline([ ('RF', RandomForestClassifier(random_state=seed, n_estimators=n_estimators))
                              ])))

pipelines.append(('ET',
                  Pipeline([ ('ET', ExtraTreesClassifier(random_state=seed, n_estimators=n_estimators))
                              ])))


#pipelines.append(('XGB',
#                  Pipeline([ ('XGB', XGBClassifier(random_state=seed))
#                              ])))

results, names, times  = [], [] , []
num_folds = 10
scoring = 'accuracy'

for name, model in pipelines:
    start = time()
    kfold = StratifiedKFold(n_splits=num_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring = scoring,n_jobs=-1) 
    t_elapsed = time() - start
    results.append(cv_results)
    names.append(name)
    times.append(t_elapsed)
    msg = "%s: %f (+/- %f) performed in %f seconds" % (name, 100*cv_results.mean(), 
                                                       100*cv_results.std(), t_elapsed)
    print(msg)
# Out:
# MNB: nan (+/- nan) performed in 4.227087 seconds
# CATBoost: 90.562697 (+/- 0.420266) performed in 1.688459 seconds
# RF: 89.811624 (+/- 0.383643) performed in 1.186764 seconds
# ET: 89.847023 (+/- 0.345379) performed in 0.761380 seconds

# %%
classifier4=lgb.LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.7,
        gamma=0.1, importance_type='split', learning_rate=0.1, max_depth=5,
        min_child_samples=20, min_child_weight=3, min_split_gain=0.0,
        n_estimators=400, n_jobs=-1, num_leaves=50, objective=None,
        random_state=100, reg_alpha=0.0, reg_lambda=0.0, silent=True,
        subsample=1.0, subsample_for_bin=20000, subsample_freq=1)
classifier4.fit(X_train,y_train)
y_predict = classifier4.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.9081042821752978
# col_0      0    1
# labels
# 0       7224  241
# 1        538  474
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7465
#            1       0.66      0.47      0.55      1012
#
#     accuracy                           0.91      8477
#    macro avg       0.80      0.72      0.75      8477
# weighted avg       0.90      0.91      0.90      8477

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7465
#            1       0.66      0.47      0.55      1012
#
#     accuracy                           0.91      8477
#    macro avg       0.80      0.72      0.75      8477
# weighted avg       0.90      0.91      0.90      8477

# %%
from tpot import TPOTClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.75, test_size=0.25)

tpot = TPOTClassifier(generations=5, population_size=50, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_digits_pipeline.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9052337537620087
# Generation 2 - Current best internal CV score: 0.9052337537620087
# Generation 3 - Current best internal CV score: 0.9059022246106888
# Generation 4 - Current best internal CV score: 0.9059022246106888
# Generation 5 - Current best internal CV score: 0.9059022246106888
#
# Best pipeline: XGBClassifier(input_matrix, learning_rate=0.1, max_depth=5, min_child_weight=9, n_estimators=100, nthread=1, subsample=0.8500000000000001)
# 0.9037395304942787

# %%
y_predict = tpot.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
# Out:
# 0.9037395304942787
# col_0      0    1
# labels
# 0       7275  247
# 1        569  386

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7522
#            1       0.61      0.40      0.49       955
#
#     accuracy                           0.90      8477
#    macro avg       0.77      0.69      0.72      8477
# weighted avg       0.89      0.90      0.89      8477

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
# generate dataset
X, y = make_classification(data=train , n_samples=10000, n_features=2, n_redundant=0,
n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=3)
# define model
model = DecisionTreeClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-07b6ce8b7f60> in <module>
#       6 # generate dataset
#       7 X, y = make_classification(data=train , n_samples=10000, n_features=2, n_redundant=0,
# ----> 8 n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=3)
#       9 # define model
#      10 model = DecisionTreeClassifier()
#
# TypeError: make_classification() got an unexpected keyword argument 'data'

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
import numpy as np


data = make_classification(n_samples=10000, n_features=3, n_informative=1,
                           n_redundant=1, n_classes=2,
                           n_clusters_per_class=1, random_state=1729)
X = data[0]  # Your predictors.
y = data[1]  # Your target.

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

rf = RandomForestClassifier()  # Initialise classifier.

# Estimate classifier's performance on unseen data via cross-validation.
print('Cross-val score is {}'
      .format(np.mean(
              cross_val_score(rf, X_train, y_train, cv=5, scoring='roc_auc'))))

# Train on entire training set, evaluate on test set.
rf.fit(X_train, y_train)
print('Test score is {}.'
      .format(roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])))
# Out:
# Cross-val score is 0.9430485109983981
# Test score is 0.9475392394658861.

# %%
print(data)
# Out:
# (array([[ 1.05460601,  0.54021775, -0.33940229],
#        [ 0.87418684, -0.35061142, -0.28133826],
#        [ 0.02329413, -1.6821917 , -0.00749671],
#        ...,
#        [ 1.22617569,  0.738376  , -0.39461831],
#        [ 0.90195887,  0.36188627, -0.29027609],
#        [ 1.78549507, -0.57588404, -0.57462324]]), array([1, 1, 1, ..., 1, 1, 1]))

# %%
data
# Out:
# (array([[ 1.05460601,  0.54021775, -0.33940229],
#         [ 0.87418684, -0.35061142, -0.28133826],
#         [ 0.02329413, -1.6821917 , -0.00749671],
#         ...,
#         [ 1.22617569,  0.738376  , -0.39461831],
#         [ 0.90195887,  0.36188627, -0.29027609],
#         [ 1.78549507, -0.57588404, -0.57462324]]),
#  array([1, 1, 1, ..., 1, 1, 1]))

# %%
forest = RandomForestClassifier(n_estimators = 150)
forest.fit(X_train, y_train)
print('Score: ', forest.score(X_test, y_test))
predictions = forest.predict(X_test)
# Out:
# Score:  0.9063347882505604

# %%
y_predict = forest.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
# Out:
# 0.9042113955408753
# col_0      0    1
# labels
# 0       7248  217
# 1        595  417

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.87

# %%
X_train.columns
# Out:
# Index(['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
#        'feature_2', 'feature_13', 'feature_5', 'feature_11', 'feature_15',
#        'feature_7', 'feature_4'],
#       dtype='object')

# %%
 # load libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostRegressor

model = CatBoostRegressor()
parameters = {'depth'         : [6,8,10],
                  'learning_rate' : [0.01, 0.05, 0.1],
                  'iterations'    : [30, 50, 100]
                 }
grid = GridSearchCV(estimator=model, param_grid = parameters, cv = 2, n_jobs=-1)
grid.fit(X_train, y_train)    

# Results from Grid Search
print("\n========================================================")
print(" Results from Grid Search " )
print("========================================================")    

print("\n The best estimator across ALL searched params:\n",
      grid.best_estimator_)

print("\n The best score across ALL searched params:\n",
      grid.best_score_)

print("\n The best parameters across ALL searched params:\n",
      grid.best_params_)

print("\n ")
# Out:
# 0:	learn: 0.3114351	total: 15.6ms	remaining: 1.55s
# 1:	learn: 0.3037003	total: 26.2ms	remaining: 1.28s
# 2:	learn: 0.2974251	total: 37ms	remaining: 1.2s
# 3:	learn: 0.2920021	total: 46.9ms	remaining: 1.13s
# 4:	learn: 0.2874394	total: 57.2ms	remaining: 1.09s
# 5:	learn: 0.2831463	total: 68ms	remaining: 1.07s
# 6:	learn: 0.2794571	total: 79.1ms	remaining: 1.05s
# 7:	learn: 0.2763743	total: 89.4ms	remaining: 1.03s
# 8:	learn: 0.2738522	total: 99.6ms	remaining: 1.01s
# 9:	learn: 0.2716248	total: 111ms	remaining: 995ms
# 10:	learn: 0.2695521	total: 124ms	remaining: 1s
# 11:	learn: 0.2677327	total: 134ms	remaining: 981ms
# 12:	learn: 0.2660437	total: 143ms	remaining: 958ms
# 13:	learn: 0.2647545	total: 153ms	remaining: 939ms
# 14:	learn: 0.2633927	total: 163ms	remaining: 923ms
# 15:	learn: 0.2621493	total: 173ms	remaining: 909ms
# 16:	learn: 0.2611194	total: 184ms	remaining: 899ms
# 17:	learn: 0.2600193	total: 194ms	remaining: 884ms
# 18:	learn: 0.2592400	total: 203ms	remaining: 867ms
# ...

# %% [markdown]
# model1=RandomForestClassifier(n_estimators=100,min_samples_leaf=4,class_weight="balanced", criterion='entropy')
# model1.fit(X_train,y_train)
# from sklearn.model_selection import cross_val_score
# cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
# y_predict = model1.predict(X_test)
# print(accuracy_score(y_test, y_predict))
# print(pd.crosstab(y_test, y_predict))
# print(classification_report(y_test, y_predict))

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_samples_leaf' : [2,5,7,9],
    'criterion' : ['gini','entropy']
    }

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_)
y_predict = CV_rfc.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt', 'min_samples_leaf': 2, 'n_estimators': 200}
# 0.906806653297157
# col_0      0    1
# labels
# 0       7252  213
# 1        577  435
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      7465
#            1       0.67      0.43      0.52      1012
#
#     accuracy                           0.91      8477
#    macro avg       0.80      0.70      0.74      8477
# weighted avg       0.90      0.91      0.90      8477

# %%
model1=RandomForestClassifier(n_estimators=200,min_samples_leaf=4,class_weight="balanced", criterion='gini',max_features='sqrt')
model1.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model1.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8968974873186268
# col_0      0    1
# labels
# 0       6899  566
# 1        308  704
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      7465
#            1       0.55      0.70      0.62      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.76      0.81      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
svc=SVC(kernel='rbf',class_weight={0:2,1:8}, C=1.0, random_state=100,gamma='auto')
svc.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = svc.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8796744131178483
# col_0      0    1
# labels
# 0       6732  733
# 1        287  725
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      7465
#            1       0.50      0.72      0.59      1012
#
#     accuracy                           0.88      8477
#    macro avg       0.73      0.81      0.76      8477
# weighted avg       0.90      0.88      0.89      8477

# %%
train2.shape
# Out:
# (33908, 12)

# %%
train2.head()
# Out:
#    feature_3  feature_14  feature_1  feature_0  feature_2  feature_13  \
# 0  -0.012283          10  -0.424429  -0.276515   1.344997           0
# 1  -0.979179           0   0.150991   0.853573   0.503892           0
# 2  -0.703478           5  -0.173832   0.947747   1.825628           0
# 3  -0.039464           5  -0.381404   0.853573   0.984523           0
# 4  -0.097711           8   1.590527   1.324443  -1.178318           0
#
#    feature_5  feature_11  feature_15  feature_7  feature_4  labels
# 0   1.076648           0           2          3   0.076230       1
# 1  -0.411453           1           3          4  -0.569351       0
# 2  -0.411453           0           3          6   0.076230       0
# 3  -0.411453           1           3          4  -0.569351       0
# 4  -0.411453           0           3          0  -0.246560       0

# %%
sns.boxplot(train2.feature_4)

# %%
train2.feature_4.min(),train2.feature_4.max(),train2.feature_4.median()
# Out:
# (-0.5693506376457914, 19.443647344339787, -0.2465603476137659)

# %%
sns.boxplot(test2.feature_4)

# %%
print(train2.feature_4[train2.feature_4>=10])
# Out:
# 54       10.405519
# 3434     10.405519
# 3903     11.373890
# 4442     10.405519
# 5077     11.051100
# 7028     12.987842
# 7380     10.728310
# 7781     12.987842
# 11921    15.247374
# 12101    13.310632
# 12656    10.082729
# 15235    11.373890
# 15728    15.247374
# 17893    19.443647
# 18859    10.082729
# 20894    17.829696
# 21465    13.956212
# 22734    12.342261
# 28512    12.987842
# 28600    10.405519
# 29597    10.728310
# 30031    15.570164
# 32159    16.861325
# 32542    10.728310
# 33088    11.373890
# 33508    10.728310
# Name: feature_4, dtype: float64

# %%
train3=train2.drop(train2[train2.feature_4 >= 1].index)

# %%
train3.shape
# Out:
# (30660, 12)

# %%
train3.head()
# Out:
#    feature_3  feature_14  feature_1  feature_0  feature_2  feature_13  \
# 0  -0.012283          10  -0.424429  -0.276515   1.344997           0
# 1  -0.979179           0   0.150991   0.853573   0.503892           0
# 2  -0.703478           5  -0.173832   0.947747   1.825628           0
# 3  -0.039464           5  -0.381404   0.853573   0.984523           0
# 4  -0.097711           8   1.590527   1.324443  -1.178318           0
#
#    feature_5  feature_11  feature_15  feature_7  feature_4  labels
# 0   1.076648           0           2          3   0.076230       1
# 1  -0.411453           1           3          4  -0.569351       0
# 2  -0.411453           0           3          6   0.076230       0
# 3  -0.411453           1           3          4  -0.569351       0
# 4  -0.411453           0           3          0  -0.246560       0

# %%
X=train3.drop(['labels'],axis=1)
y=train3['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((22995, 11), (7665, 11), (22995,), (7665,))

# %%
svc=SVC(kernel='rbf',class_weight={0:2,1:8}, C=1.0, random_state=100,gamma='auto')
svc.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = svc.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8781408517164091
# col_0      0    1
# labels
# 0       6726  739
# 1        294  718
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      7465
#            1       0.49      0.71      0.58      1012
#
#     accuracy                           0.88      8477
#    macro avg       0.73      0.81      0.76      8477
# weighted avg       0.90      0.88      0.89      8477

# %%
model1=RandomForestClassifier(n_estimators=250,min_samples_leaf=5,class_weight={0:2,1:8}, criterion='gini',max_features='sqrt')
model1.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model1.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8892367906066536
# col_0      0    1
# labels
# 0       6204  536
# 1        313  612
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94      6740
#            1       0.53      0.66      0.59       925
#
#     accuracy                           0.89      7665
#    macro avg       0.74      0.79      0.76      7665
# weighted avg       0.90      0.89      0.89      7665

# %%
sns.boxplot(train3.feature_4)

# %%
X_train.columns
# Out:
# Index(['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
#        'feature_13', 'feature_5', 'feature_11', 'feature_15', 'feature_7',
#        'feature_4'],
#       dtype='object')

# %%
test2.columns
# Out:
# Index(['feature_3', 'feature_14', 'feature_1', 'feature_0', 'feature_2',
#        'feature_13', 'feature_5', 'feature_11', 'feature_15', 'feature_7',
#        'feature_4'],
#       dtype='object')

# %%
predict_test1 = model1.predict(test2)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_samples_leaf' : [2,5,7,9],
    'criterion' : ['gini','entropy']
    }

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_)
y_predict = CV_rfc.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# {'criterion': 'gini', 'max_features': 'auto', 'min_samples_leaf': 2, 'n_estimators': 700}
# 0.8984996738421396
# col_0      0    1
# labels
# 0       6501  239
# 1        539  386
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      6740
#            1       0.62      0.42      0.50       925
#
#     accuracy                           0.90      7665
#    macro avg       0.77      0.69      0.72      7665
# weighted avg       0.89      0.90      0.89      7665

# %%
X=train.drop(['labels'],axis=1)
y=train['labels']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((25431, 16), (8477, 16), (25431,), (8477,))

# %%
model1=RandomForestClassifier(n_estimators=200,min_samples_leaf=5,class_weight={0:2,1:8}, criterion='gini',max_features='auto')
model1.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = model1.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8991388462899611
# col_0      0    1
# labels
# 0       6959  506
# 1        349  663
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      7465
#            1       0.57      0.66      0.61      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.76      0.79      0.78      8477
# weighted avg       0.91      0.90      0.90      8477

# %%
test.shape

# %%
predict_test1 = model1.predict(test)
submission1 = pd.DataFrame(predict_test1)
submission1.to_excel("submissionInspectionResults_Santosh-1.xls",index=False)

# %%
l=list(df.columns)
l[0:len(l)-1]
# Out:
# ['feature_3',
#  'feature_1',
#  'feature_0',
#  'feature_2',
#  'feature_14',
#  'feature_15',
#  'feature_5',
#  'feature_7',
#  'feature_4']

# %%
for i in range(len(l)-1):
    sns.boxplot(x='labels',y=l[i], data=df)
    plt.figure()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train,y_train)
from sklearn.model_selection import cross_val_score
cross_val_score(knn, X_train, y_train, cv=5, scoring='accuracy').mean()
y_predict = knn.predict(X_test)
print(accuracy_score(y_test, y_predict))
print(pd.crosstab(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# 0.8967795210569777
# col_0      0    1
# labels
# 0       7362  103
# 1        772  240
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.94      7465
#            1       0.70      0.24      0.35      1012
#
#     accuracy                           0.90      8477
#    macro avg       0.80      0.61      0.65      8477
# weighted avg       0.88      0.90      0.87      8477

# %%
print("Misclassification error rate:",round(np.mean(y_predict!=y_test),3))
# Out:
# Misclassification error rate: 0.105

# %%
error_rate = []

# Will take some time
for i in range(1,60):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,60),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=8)
plt.title('Error Rate vs. K Value', fontsize=20)
plt.xlabel('K',fontsize=15)
plt.ylabel('Error (misclassification) Rate',fontsize=15)
# Out:
# Text(0, 0.5, 'Error (misclassification) Rate')
